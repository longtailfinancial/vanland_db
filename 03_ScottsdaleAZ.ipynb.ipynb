# %%
# default_exp scraper

# %% [markdown]
# # Scraper
#
# > This module is used to scrape https://www.point2homes.com for all residential in Scottsdale Arizona

# %%
#hide
from nbdev.showdoc import *
from lxml.etree import HTML
from selenium import webdriver
from selenium.webdriver.common.by import By
import xmltodict as xd
from time import sleep
from lxml import etree
import pandas as pd

# %%
def get_text(xpath):
    return re.sub('<[^<]+?>', '', etree.tostring(xpath, method='html', with_tail=False).decode('ascii')).replace('\n', '').replace('  ', '')

# %%
def extract_properties(land):
    data = xd.parse(etree.tostring(land))['div']['div']
    try:
        address = data[0]['@data-address']
    except:
        print("Missing Address")
        address = ''
    try:
        price = data[1]['@data-price']
        try:
            lot_size = data[2]['ul']['li'][0]['strong']
        except:
#             print("Missing lot_size")
            lot_size = ''
        try:
            beds = data[2]['ul']['li'][0]['strong']
        except:
#             print("missing beds")
            beds = ''
        try:
            baths = data[2]['ul']['li'][1]['strong']
        except:
#             print("missing baths")
            baths = ''
        try:
            sqft = data[2]['ul']['li'][2]['strong']
        except:
#             print("missing sqft")
            sqft = ''
        try:
            property_type = data[2]['ul']['li'][3]['#text']
        except:
#             print("Missing property_type")
            property_type = ''
        link = data[4]['a']['@href']
        properties = {
            'address': address,
            'price':price,
            'lot_size':lot_size,
            'beds':beds,
            'baths':baths,
            'sqft':sqft,
            'property_type':property_type,
            'link':link
        }
        return properties
    except Exception as e:
        raise e
        print(f'Failed on {address}')

# %%
def read_land_column(lands):
    land_list = []
    for land in lands:
        land_list.append(extract_properties(land))
    return land_list

# %%
url = "https://www.point2homes.com/CA/Real-Estate-Maps/BC/Vancouver-Island.html"
browser = webdriver.Firefox()
browser.get(url)

# %%
page_source = HTML(browser.page_source)

lands = page_source.xpath("//div[@class='item_information']")

# %%
land_data = []

# %%
while(1):
    # Read Page
    page_source = HTML(browser.page_source)

    # Extract Land Column
    lands = page_source.xpath("//div[@class='item_information']")

    # Append data
    land_data = land_data + read_land_column(lands)
    
    # Report in.
    print(f"Successfully Scraped: {len(lands)}")

    # Go to next page
    next_button = browser.find_element(By.XPATH, "//a[starts-with(@class,'pager-next')]")
    if 'disabled' in next_button.get_attribute('class'):
        break
    else:
        print('Next Page')
        next_button.click()
        sleep(8)
# Out:
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Successfully Scraped: 100
# Next Page
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Successfully Scraped: 100
# Next Page
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Successfully Scraped: 100
# Next Page
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Successfully Scraped: 100
# Next Page
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Successfully Scraped: 100
# Next Page
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing lot_size
# missing beds
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Successfully Scraped: 100
# Next Page
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Successfully Scraped: 99
# Next Page
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Successfully Scraped: 100
# Next Page
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Successfully Scraped: 100
# Next Page
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Successfully Scraped: 100
# Next Page
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Successfully Scraped: 100
# Next Page
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing baths
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Successfully Scraped: 100
# Next Page
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# missing sqft
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Missing property_type
# Successfully Scraped: 100

# %%
df = pd.DataFrame(land_data)

# %%
df
# Out:
#                       address             price lot_size beds baths   sqft  \
# 0           324 Archibald rd      $325,000 CAD         2    2     2  1,215
# 1              4825 Hazel St      $688,000 CAD         2    2     2  1,185
# 2             969 Walfred Rd      $749,900 CAD         4    4     4  3,710
# 3        196/198 Cooper Road    $1,295,000 CAD         3    3     3  2,861
# 4     77 - 5700 Jinkerson Rd      $628,000 CAD         2    2     3  2,092
# ...                       ...               ...      ...  ...   ...    ...
# 6491         1255 GRIEVE AVE      $449,000 CAD         3    3     2  1,271
# 6492    203 ARROWSTONE DRIVE      $499,900 CAD         4    4     3  1,604
# 6493      19283 122A AVENUE 8     $699,000 CAD         3    3     3  1,691
# 6494         20850 52 AVENUE      $699,000 CAD         3    3     2  1,050
# 6495      4851 70 Avenue, NE      $377,000 CAD         3    3     1  1,204
#
#      property_type                                               link
# 0                   /CA/Home-For-Sale/BC/Thompson-Okanagan/Thompso...
# 1      Residential  /CA/Home-For-Sale/BC/Burnaby/Marlborough/4825-...
# 2                   /CA/Home-For-Sale/BC/Langford/Walfred/969-Walf...
# 3                   /CA/Home-For-Sale/BC/Thompson-Okanagan/North-O...
# 4      Residential  /CA/Home-For-Sale/BC/Chilliwack/Promontory/77-...
# ...            ...                                                ...
# 6491                /CA/Home-For-Sale/BC/Vancouver-Island/1255-GRI...
# 6492                /CA/Home-For-Sale/BC/Kamloops/Sahali/203-ARROW...
# 6493         Condo  /CA/Condo-For-Sale/BC/Pitt-Meadows/Central-Mea...
# 6494                /CA/Home-For-Sale/BC/Langley/Blacklock/20850-5...
# 6495                /CA/Home-For-Sale/BC/Thompson-Okanagan/Columbi...
#
# [6496 rows x 8 columns]

# %%
import re

# %%
def extract_numbers(s):
    return float(''.join(re.findall("[-+]?\d*\.\d+|\d+", s)) or 0)

# %%
df['price_float'] = df['price'].apply(extract_numbers)

# %%
df['sqft_float'] = df['sqft'].apply(extract_numbers)

# %%
df['Dollar per Sqft'] = df['price_float'] / df['sqft_float']

# %%
df = df.sort_values('Dollar per Sqft')

# %%
df['link'] = 'https://www.point2homes.com' + df['link']

# %%
df['Dollar per Sqft'] = df['Dollar per Sqft'].apply(lambda x: str(round(x, 2)))

# %%
df = df.drop_duplicates('address')

# %%
df.to_csv('vanland_homes.csv', index=False)

# %%
df[df['baths'] >= 3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-2983fc6f0615> in <module>
# ----> 1 df[df['baths'] >= 3]
#
# ~/.virtualenvs/LTF/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# ~/.virtualenvs/LTF/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# ~/.virtualenvs/LTF/lib/python3.6/site-packages/pandas/core/ops/__init__.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1067         result = libops.vec_compare(x, y, op)
#    1068     else:
# -> 1069         result = libops.scalar_compare(x, y, op)
#    1070     return result
#    1071
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
df.to_csv("ScottsdaleAZ_raw.csv", index=False)

# %%
df.head(100).to_csv("ScottsdaleAZTop100.csv", index=False)

# %%
len(pages)extract_numbers
# Out:
# 121

# %%
df = pd.DataFrame(land_list)

# %%
df.sort_values('price_float').to_csv('VancouverIsland-Cheapest.csv',index=False)

# %%
df.iloc[92].values
# Out:
# array(['LT 38 RUXTON ISLAND ', '$75,000 CAD', '2.15 ac', 'Land',
#        '/CA/Vacant-Land-For-Sale/BC/Vancouver-Island/Cowichan-Valley/LT-38-RUXTON-ISLAND/88932209.html'],
#       dtype=object)

# %%
next_page = browser.find_element(By.XPATH, "//input[starts-with(@name,'username')]")
password = browser.find_element(By.XPATH, "//input[starts-with(@name,'password')]")

username.send_keys("Carole@impactisi.com")
password.send_keys("password123")
browser.find_element(By.XPATH, "//input[starts-with(@name,'Login')]").click()

# %%
pager-next

# %%
# price, ac, price/ac, datetime, id, area

# %%
1038 / 100
# Out:
# 10.38

# %%
item = {
    'address':
    'price':
    'characteristics':
    'labels':
    'detail_link'
}
# Out:
#   File "<ipython-input-111-5589d66c2c9c>", line 3
#     'price':
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
from lxml import etree

# %%
etree.tostring(tree)
# Out:
# b'<div class="item_information">\n        <div class="item_address" data-url="/CA/Vacant-Land-For-Sale/BC/Nanoose-Bay/LOT-1-Oak-Leaf-Drive/82258309.html" data-tracking="" data-address="LOT 1 Oak Leaf Drive ">\n            <div class="address-container">\n                <span>LOT 1 Oak Leaf Drive </span>\n            </div>\n\n        </div>\n<div class="price " data-price="$799,000 CAD">\n    <span class="green">\n            <span> $799,000 CAD</span>\n    </span>\n\n</div>\n        <div class="characteristics-cnt">\n\n\n<ul>\n                    <li data-label="Lot Size" class="ic-lotsize">\n            <strong>0.842 ac</strong> <span class="gray">Lot Size</span>\n        </li>\n            <li class="property-type ic-proptype">\n            Land\n        </li>\n</ul>\n\n\n        </div>\n        <div class="labels">\n            <div class="featured-icon" title="Featured"/>\n\n        </div>\n        <div class="lnk_details">\n            <a rel="" href="/CA/Vacant-Land-For-Sale/BC/Nanoose-Bay/LOT-1-Oak-Leaf-Drive/82258309.html" onclick="featuredListingClick(82258309, 2228339, \'CA\', 737097); psrk.cancelBubble(event);" title="Land - LOT 1 Oak Leaf Drive " target="_blank"><span>Details</span></a>\n        </div>\n\n    </div>\n    '

# %%
etree.tostringlist(tree)
# Out:
# [b'<div class="item_information">\n        <div class="item_address" data-url="/CA/Vacant-Land-For-Sale/BC/Nanoose-Bay/LOT-1-Oak-Leaf-Drive/82258309.html" data-tracking="" data-address="LOT 1 Oak Leaf Drive ">\n            <div class="address-container">\n                <span>LOT 1 Oak Leaf Drive </span>\n            </div>\n\n        </div>\n<div class="price " data-price="$799,000 CAD">\n    <span class="green">\n            <span> $799,000 CAD</span>\n    </span>\n\n</div>\n        <div class="characteristics-cnt">\n\n\n<ul>\n                    <li data-label="Lot Size" class="ic-lotsize">\n            <strong>0.842 ac</strong> <span class="gray">Lot Size</span>\n        </li>\n            <li class="property-type ic-proptype">\n            Land\n        </li>\n</ul>\n\n\n        </div>\n        <div class="labels">\n            <div class="featured-icon" title="Featured"/>\n\n        </div>\n        <div class="lnk_details">\n            <a rel="" href="/CA/Vacant-Land-For-Sale/BC/Nanoose-Bay/LOT-1-Oak-Leaf-Drive/82258309.html" onclick="featuredListingClick(82258309, 2228339, \'CA\', 737097); psrk.cancelBubble(event);" title="Land - LOT 1 Oak Leaf Drive " target="_blank"><span>Details</span></a>\n        </div>\n\n    </div>\n    ']

# %%
pd.read_html(tree)
# Out:
# /usr/lib/python3.6/urllib/parse.py:107: FutureWarning: The behavior of this method will change in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.
#   return tuple(x.decode(encoding, errors) if x else '' for x in args)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-388389fa760c> in <module>
# ----> 1 pd.read_html(tree)
#
# ~/.virtualenvs/LTF/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# ~/.virtualenvs/LTF/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# --> 912         raise_with_traceback(retained)
#     913
#     914     ret = []
#
# ~/.virtualenvs/LTF/lib/python3.6/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#      45     if traceback == Ellipsis:
#      46         _, _, traceback = sys.exc_info()
# ---> 47     raise exc.with_traceback(traceback)
#      48
#      49
#
# TypeError: Cannot read object of type '_Element'

# %%
tree = lands[0]

# %%
price = tree.xpath("//div[@class='price']")

# %%
price
# Out:
# [<Element div at 0x7fb8ac045a88>]

# %%
e = price[0]

# %%
e.text
# Out:
# '$47,900 CAD'

# %%
address = tree.xpath("//div[@class='item_address']")

# %%
address[0].attrib['data-address']
# Out:
# 'LOT 1 Oak Leaf Drive '

# %%
data-address

# %%
descriptions = tree.xpath("//div[@class='info member-info']")
links = tree.xpath("//a[@class='learn-more']")

# %%
lands
# Out:
# [<Element div at 0x7fb8ac0d0408>,
#  <Element div at 0x7fb8ac0d0d08>,
#  <Element div at 0x7fb8ac0f57c8>,
#  <Element div at 0x7fb8ac045448>,
#  <Element div at 0x7fb8ac045488>,
#  <Element div at 0x7fb8ac045508>,
#  <Element div at 0x7fb896df03c8>,
#  <Element div at 0x7fb896df0408>,
#  <Element div at 0x7fb896df0448>,
#  <Element div at 0x7fb8ac0454c8>,
#  <Element div at 0x7fb896df0488>,
#  <Element div at 0x7fb896df04c8>,
#  <Element div at 0x7fb896df0508>,
#  <Element div at 0x7fb896df0548>,
#  <Element div at 0x7fb896df0588>,
#  <Element div at 0x7fb896df05c8>,
#  <Element div at 0x7fb896df0608>,
#  <Element div at 0x7fb896df0648>,
#  <Element div at 0x7fb896df0688>,
#  <Element div at 0x7fb896df06c8>,
#  <Element div at 0x7fb896df0708>,
#  <Element div at 0x7fb896df0748>,
#  <Element div at 0x7fb896df0788>,
#  <Element div at 0x7fb896df07c8>,
#  <Element div at 0x7fb896df0808>,
#  <Element div at 0x7fb896df0848>,
#  <Element div at 0x7fb896df0888>,
#  <Element div at 0x7fb896df08c8>,
#  <Element div at 0x7fb896df0908>,
#  <Element div at 0x7fb896df0948>,
#  <Element div at 0x7fb896df0988>,
#  <Element div at 0x7fb896df09c8>,
#  <Element div at 0x7fb896df0a08>,
#  <Element div at 0x7fb896df0a48>,
#  <Element div at 0x7fb896df0a88>,
#  <Element div at 0x7fb896df0ac8>,
#  <Element div at 0x7fb896df0b08>,
#  <Element div at 0x7fb896df0b48>,
#  <Element div at 0x7fb896df0b88>,
#  <Element div at 0x7fb896df0bc8>,
#  <Element div at 0x7fb896df0c08>,
#  <Element div at 0x7fb896df0c48>,
#  <Element div at 0x7fb896df0c88>,
#  <Element div at 0x7fb896df0cc8>,
#  <Element div at 0x7fb896df0d08>,
#  <Element div at 0x7fb896df0d48>,
#  <Element div at 0x7fb896df0d88>,
#  <Element div at 0x7fb896df0dc8>,
#  <Element div at 0x7fb896df0e08>,
#  <Element div at 0x7fb896df0e48>,
#  <Element div at 0x7fb896df0e88>,
#  <Element div at 0x7fb896df0ec8>,
#  <Element div at 0x7fb896df0f08>,
#  <Element div at 0x7fb896df0f48>,
#  <Element div at 0x7fb896df0f88>,
#  <Element div at 0x7fb896df0fc8>,
#  <Element div at 0x7fb8ac073048>,
#  <Element div at 0x7fb8ac073088>,
#  <Element div at 0x7fb8ac0730c8>,
#  <Element div at 0x7fb8ac073108>,
#  <Element div at 0x7fb8ac073148>,
#  <Element div at 0x7fb8ac073188>,
#  <Element div at 0x7fb8ac0731c8>,
#  <Element div at 0x7fb8ac073208>,
#  <Element div at 0x7fb8ac073248>,
#  <Element div at 0x7fb8ac073288>,
#  <Element div at 0x7fb8ac0732c8>,
#  <Element div at 0x7fb8ac073308>,
#  <Element div at 0x7fb8ac073348>,
#  <Element div at 0x7fb8ac073388>,
#  <Element div at 0x7fb8ac0733c8>,
#  <Element div at 0x7fb8ac073408>,
#  <Element div at 0x7fb8ac073448>,
#  <Element div at 0x7fb8ac073488>,
#  <Element div at 0x7fb8ac0734c8>,
#  <Element div at 0x7fb8ac073508>,
#  <Element div at 0x7fb8ac073548>,
#  <Element div at 0x7fb8ac073588>,
#  <Element div at 0x7fb8ac0735c8>,
#  <Element div at 0x7fb8ac073608>,
#  <Element div at 0x7fb8ac073648>,
#  <Element div at 0x7fb8ac073688>,
#  <Element div at 0x7fb8ac0736c8>,
#  <Element div at 0x7fb8ac073708>,
#  <Element div at 0x7fb8ac073748>,
#  <Element div at 0x7fb8ac073788>,
#  <Element div at 0x7fb8ac0737c8>,
#  <Element div at 0x7fb8ac073808>,
#  <Element div at 0x7fb8ac073848>,
#  <Element div at 0x7fb8ac073888>,
#  <Element div at 0x7fb8ac0738c8>,
#  <Element div at 0x7fb8ac073908>,
#  <Element div at 0x7fb8ac073948>,
#  <Element div at 0x7fb8ac073988>,
#  <Element div at 0x7fb8ac0739c8>,
#  <Element div at 0x7fb8ac073a08>,
#  <Element div at 0x7fb8ac073a48>,
#  <Element div at 0x7fb8ac073a88>,
#  <Element div at 0x7fb8ac073ac8>,
#  <Element div at 0x7fb8ac073b08>]
